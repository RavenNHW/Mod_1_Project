# %% [markdown]
# **Import Revenue Data**

# %%
import pandas as pd
import numpy as np
budget_df = pd.read_csv('data/hollywood_domestic_boxoffice.csv', header=0)

#Update column names to match.  Drop unneeded columns
budget_df.rename(columns = {"title": "primary_title"}, inplace = True)
budget_df.drop(columns = ["rank", "studio"], inplace = True)

# #Add in year of release for accuracy
budget_df['title_year'] = budget_df['primary_title'] + ' - ' + budget_df['year'].astype(str)
budget_df.head()
# Out:
#                   primary_title  lifetime_gross  year  \
# 0  Star Wars: The Force Awakens       936662225  2015
# 1             Avengers: Endgame       857190335  2019
# 2                        Avatar       760507625  2009
# 3                 Black Panther       700059566  2018
# 4        Avengers: Infinity War       678815482  2018
#
#                             title_year
# 0  Star Wars: The Force Awakens - 2015
# 1             Avengers: Endgame - 2019
# 2                        Avatar - 2009
# 3                 Black Panther - 2018
# 4        Avengers: Infinity War - 2018

# %%
#No null values
budget_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16542 entries, 0 to 16541
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   primary_title   16542 non-null  object
#  1   lifetime_gross  16542 non-null  int64
#  2   year            16542 non-null  int64
#  3   title_year      16542 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 517.1+ KB

# %% [markdown]
# **Import IMDB Title Data**

# %%
##need: Primary Title, Genres
##match on: title_year

imdb_titles_df = pd.read_csv('data/imdb.title.basics.csv.gz')
# imdb_titles_df = imdb_titles_df.drop(columns = ["start_year", "runtime_minutes"])

# %%
#Some null values in runtime, genre
imdb_titles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# titles_and_rev = budget_df.merge(imdb_titles_df, how='left', on='title_year')
# titles_and_rev.head()

# %%
#Only 3k out of 17k have IMDB data
#Need to bring in title akas to make this work
# titles_and_rev.info()

# %% [markdown]
# **Import IMDB Title AKAs**

# %%
#Get title akas and merge with imdb titles
imdb_akas_df = pd.read_csv('data/imdb.title.akas.csv.gz')
imdb_akas_df.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
#Drop columns.  We only need id and title
imdb_akas_df = imdb_akas_df[['title_id', 'title']]

# %%
#No null values
imdb_akas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   title_id  331703 non-null  object
#  1   title     331703 non-null  object
# dtypes: object(2)
# memory usage: 5.1+ MB

# %% [markdown]
# **Merge Title AKAs with Title Basics**

# %%
#May not be alternate titles for each movie.  Should add them only where appropriate - NOT LEFT JOIN
#Merge with imdb titles so that there is a full row of data for each alternate title
#Merge on tconst

#rename column to match
imdb_akas_df.rename(columns = {"title_id": "tconst", "title": "alternate_title"}, inplace = True)

# %%
titles_with_akas = imdb_akas_df.merge(imdb_titles_df, how='left', on='tconst')
titles_with_akas.head(20)
# Out:
#        tconst                          alternate_title   primary_title  \
# 0   tt0369610                            Джурасик свят  Jurassic World
# 1   tt0369610                        Jurashikku warudo  Jurassic World
# 14                           Jurassic World                   Jurassic World
# ...                                     ...                              ...
# 331688  Dusan Vukotic Croatian Oscar Winner  Dusan Vukotic hrvatski okarovac
# 331690           Anderswo. Allein in Afrika       Anderswo. Allein in Afrika
# 331696                            Big Shark                        Big Shark
# 331698                        Farewell Song               Sayonara kuchibiru
# 331701                        The Attention                      La atención
#
#         start_year  runtime_minutes                   genres
# 5             2015            124.0  Action,Adventure,Sci-Fi
# 6             2015            124.0  Action,Adventure,Sci-Fi
# 11            2015            124.0  Action,Adventure,Sci-Fi
# 13            2015            124.0  Action,Adventure,Sci-Fi
# 14            2015            124.0  Action,Adventure,Sci-Fi
# ...            ...              ...                      ...
# 331688        2011             55.0              Documentary
# 331690        2018            103.0    Adventure,Documentary
# 331696        2019              NaN                   Horror
# 331698        2019            116.0            Music,Romance
# 331701        2019             61.0              Documentary
#
# [64834 rows x 7 columns]

# %%
titles_with_akas = titles_with_akas.drop_duplicates()

# %%
titles_with_akas
# Out:
#            tconst                          alternate_title   primary_title  \
# 0       tt0369610                            Джурасик свят  Jurassic World
# 1       tt0369610                        Jurashikku warudo  Jurassic World
# 2       tt0369610  Jurassic World: O Mundo dos Dinossauros  Jurassic World
# 3       tt0369610                  O Mundo dos Dinossauros  Jurassic World
# 4       tt0369610                           Jurassic World  Jurassic World
# ...           ...                                      ...             ...
# 331695  tt9755806                            Большая Акула       Big Shark
# 331697  tt9827784                       Sayonara kuchibiru   Farewell Song
# 331699  tt9827784                            Farewell Song   Farewell Song
# 331700  tt9880178                              La atención   The Attention
# 331702  tt9880178                            The Attention   The Attention
#
#             original_title  start_year  runtime_minutes  \
# 0           Jurassic World        2015            124.0
# 1           Jurassic World        2015            124.0
# 2           Jurassic World        2015            124.0
# 3           Jurassic World        2015            124.0
# 4           Jurassic World        2015            124.0
# ...                    ...         ...              ...
# 331695           Big Shark        2019              NaN
# 331697  Sayonara kuchibiru        2019            116.0
# 331699  Sayonara kuchibiru        2019            116.0
# 331700         La atención        2019             61.0
# 331702         La atención        2019             61.0
#
#                          genres
# 0       Action,Adventure,Sci-Fi
# 1       Action,Adventure,Sci-Fi
# 2       Action,Adventure,Sci-Fi
# 3       Action,Adventure,Sci-Fi
# 4       Action,Adventure,Sci-Fi
# ...                         ...
# 331695                   Horror
# 331697            Music,Romance
# 331699            Music,Romance
# 331700              Documentary
# 331702              Documentary
#
# [266869 rows x 7 columns]

# %%
#Convert year to string in order to create title_year column
titles_with_akas['start_year'] = titles_with_akas['start_year'].astype(str)
#Combine year and title for merging
titles_with_akas['aka_title_year'] = titles_with_akas['alternate_title'] + ' - ' + titles_with_akas['start_year']
titles_with_akas.head()
# Out:
#       tconst                          alternate_title   primary_title  \
# 0  tt0369610                            Джурасик свят  Jurassic World
# 1  tt0369610                        Jurashikku warudo  Jurassic World
# 2  tt0369610  Jurassic World: O Mundo dos Dinossauros  Jurassic World
# 3  tt0369610                  O Mundo dos Dinossauros  Jurassic World
# 4  tt0369610                           Jurassic World  Jurassic World
#
#    original_title start_year  runtime_minutes                   genres  \
# 0  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 1  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 2  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 3  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 4  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
#
#                                    aka_title_year
# 0                            Джурасик свят - 2015
# 1                        Jurashikku warudo - 2015
# 2  Jurassic World: O Mundo dos Dinossauros - 2015
# 3                  O Mundo dos Dinossauros - 2015
# 4                           Jurassic World - 2015

# %% [markdown]
# **Merge in Revenue Data for each Title AKA**

# %%
titles_and_rev = titles_with_akas.merge(budget_df, how='left', left_on='aka_title_year', right_on='title_year')
titles_and_rev.head()
# Out:
#       tconst                          alternate_title primary_title_x  \
# 0  tt0369610                            Джурасик свят  Jurassic World
# 1  tt0369610                        Jurashikku warudo  Jurassic World
# 2  tt0369610  Jurassic World: O Mundo dos Dinossauros  Jurassic World
# 3  tt0369610                  O Mundo dos Dinossauros  Jurassic World
# 4  tt0369610                           Jurassic World  Jurassic World
#
#    original_title start_year  runtime_minutes                   genres  \
# 0  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 1  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 2  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 3  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
# 4  Jurassic World       2015            124.0  Action,Adventure,Sci-Fi
#
#                                    aka_title_year primary_title_y  \
# 0                            Джурасик свят - 2015             NaN
# 1                        Jurashikku warudo - 2015             NaN
# 2  Jurassic World: O Mundo dos Dinossauros - 2015             NaN
# 3                  O Mundo dos Dinossauros - 2015             NaN
# 4                           Jurassic World - 2015  Jurassic World
#
#    lifetime_gross    year             title_year
# 0             NaN     NaN                    NaN
# 1             NaN     NaN                    NaN
# 2             NaN     NaN                    NaN
# 3             NaN     NaN                    NaN
# 4     652270625.0  2015.0  Jurassic World - 2015

# %%
#No duplicates
titles_and_rev[titles_and_rev.duplicated()]
# Out:
# Empty DataFrame
# Columns: [tconst, alternate_title, primary_title_x, original_title, start_year, runtime_minutes, genres, aka_title_year, primary_title_y, lifetime_gross, year, title_year]
# Index: []

# %%
#Still only 3200 movies with all data
titles_and_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 266869 entries, 0 to 266868
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           266869 non-null  object
#  1   alternate_title  266869 non-null  object
#  2   primary_title_x  266869 non-null  object
#  3   original_title   266859 non-null  object
#  4   start_year       266869 non-null  object
#  5   runtime_minutes  239721 non-null  float64
#  6   genres           263489 non-null  object
#  7   aka_title_year   266869 non-null  object
#  8   primary_title_y  3214 non-null    object
#  9   lifetime_gross   3214 non-null    float64
#  10  year             3214 non-null    float64
#  11  title_year       3214 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 26.5+ MB

# %%
no_nas = titles_and_rev.dropna(subset=['lifetime_gross'])

# %%
no_nas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 4 to 266833
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tconst           3214 non-null   object
#  1   alternate_title  3214 non-null   object
#  2   primary_title_x  3214 non-null   object
#  3   original_title   3214 non-null   object
#  4   start_year       3214 non-null   object
#  5   runtime_minutes  3184 non-null   float64
#  6   genres           3210 non-null   object
#  7   aka_title_year   3214 non-null   object
#  8   primary_title_y  3214 non-null   object
#  9   lifetime_gross   3214 non-null   float64
#  10  year             3214 non-null   float64
#  11  title_year       3214 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 326.4+ KB

# %% [markdown]
# **Add in principal data & names**

# %%
principals = pd.read_csv('data/imdb.title.principals.csv.gz')
names = pd.read_csv('data/imdb.name.basics.csv.gz')
names_only = names[['nconst', 'primary_name']]
principals_names = principals.merge(names_only, on='nconst', how='left')
principals_names.drop(columns = ["ordering", "job", "characters"], inplace = True)

# %% [markdown]
# **Merge Principal Data with Title Data**

# %%
#Merge on tconst
Merged_People_Movie_Data = no_nas.merge(principals_names, on = "tconst")
Merged_People_Movie_Data['category'] = Merged_People_Movie_Data['category'].replace("actress", "actor")
Merged_People_Movie_Data.head()
# Out:
#       tconst alternate_title primary_title_x  original_title start_year  \
# 0  tt0369610  Jurassic World  Jurassic World  Jurassic World       2015
# 1  tt0369610  Jurassic World  Jurassic World  Jurassic World       2015
# 2  tt0369610  Jurassic World  Jurassic World  Jurassic World       2015
# 3  tt0369610  Jurassic World  Jurassic World  Jurassic World       2015
# 4  tt0369610  Jurassic World  Jurassic World  Jurassic World       2015
#
#    runtime_minutes                   genres         aka_title_year  \
# 0            124.0  Action,Adventure,Sci-Fi  Jurassic World - 2015
# 1            124.0  Action,Adventure,Sci-Fi  Jurassic World - 2015
# 2            124.0  Action,Adventure,Sci-Fi  Jurassic World - 2015
# 3            124.0  Action,Adventure,Sci-Fi  Jurassic World - 2015
# 4            124.0  Action,Adventure,Sci-Fi  Jurassic World - 2015
#
#   primary_title_y  lifetime_gross    year             title_year     nconst  \
# 0  Jurassic World     652270625.0  2015.0  Jurassic World - 2015  nm0189777
# 1  Jurassic World     652270625.0  2015.0  Jurassic World - 2015  nm0695435
# 2  Jurassic World     652270625.0  2015.0  Jurassic World - 2015  nm0397171
# 3  Jurassic World     652270625.0  2015.0  Jurassic World - 2015  nm1339223
# 4  Jurassic World     652270625.0  2015.0  Jurassic World - 2015  nm0339460
#
#    category         primary_name
# 0  producer      Patrick Crowley
# 1     actor          Chris Pratt
# 2     actor  Bryce Dallas Howard
# 3     actor          Ty Simpkins
# 4     actor           Judy Greer

# %%
#Create df for each role
actor_df = Merged_People_Movie_Data.loc[(Merged_People_Movie_Data['category'] == 'actor')]
director_df = Merged_People_Movie_Data.loc[(Merged_People_Movie_Data['category'] == 'director')]
cinematographer_df = Merged_People_Movie_Data.loc[(Merged_People_Movie_Data['category'] == 'cinematographer')]
writer_df = Merged_People_Movie_Data.loc[(Merged_People_Movie_Data['category'] == 'writer')]

# %%
#Get top 20 actors by average domestic box office
#SUM could show better summary of track record since we have limited data
actor_df = actor_df.groupby('primary_name').mean().sort_values(by='lifetime_gross', ascending=False)
actor_df.head(50)
# Out:
#                            runtime_minutes  lifetime_gross         year
# primary_name
# Ty Simpkins                     124.000000    6.522706e+08  2015.000000
# Carrie Fisher                   152.000000    6.201814e+08  2017.000000
# Craig T. Nelson                 118.000000    6.085817e+08  2018.000000
# Sarah Vowell                    118.000000    6.085817e+08  2018.000000
# Huck Milner                     118.000000    6.085817e+08  2018.000000
# Diego Luna                      133.000000    5.321773e+08  2016.000000
# Vin Diesel                    1122.0    1.864814e+09  18132.0
# Scarlett Johansson            1150.0    1.847908e+09  20139.0
# Mark Wahlberg                 2296.0    1.784375e+09  40282.0
# Liam Hemsworth                1073.0    1.758838e+09  18124.0
# Kevin Hart                    1324.0    1.692402e+09  26196.0
# Josh Hutcherson                744.0    1.662917e+09  12079.0
# Steve Carell                  2163.0    1.615491e+09  40278.0
# Bradley Cooper                1575.0    1.606452e+09  28182.0
# John Boyega                    519.0    1.574658e+09   8060.0
# Daisy Ridley                   375.0    1.560013e+09   6048.0
# Domhnall Gleeson              1192.0    1.459273e+09  20156.0
# Jeremy Renner                 1101.0    1.424717e+09  18125.0
# Tom Hanks                     1434.0    1.422795e+09  24169.0
# Anne Hathaway                 1311.0    1.396456e+09  22150.0
# Ryan Reynolds                 1485.0    1.382642e+09  28189.0
# Cate Blanchett                1340.0    1.328061e+09  24173.0
# Woody Harrelson               1432.0    1.316853e+09  24182.0
# Bryce Dallas Howard            627.0    1.307460e+09  10065.0
# Emma Stone                    1796.0    1.288132e+09  32217.0
# Chris Pine                    1354.0    1.285640e+09  24167.0
# Kristen Wiig                  1180.0    1.225965e+09  22156.0
# Amy Adams                     1594.0    1.206103e+09  26173.0
# Channing Tatum                1719.0    1.200818e+09  30204.0
# Zoe Saldana                    934.0    1.193700e+09  16106.0
# Johnny Depp                   1539.0    1.160013e+09  26181.0
# Tom Cruise                    1242.0    1.118964e+09  20138.0
# Kevin James                    997.0    1.105105e+09  20132.0
# Tom Hardy                     1280.0    1.095216e+09  20138.0
# Owen Wilson                   1776.0    1.094106e+09  34224.0
# Jason Statham                 1259.0    1.090916e+09  22153.0
# Ian McKellen                   710.0    1.068149e+09  10068.0
# Ben Affleck                    881.0    1.060940e+09  14098.0
# Jonah Hill                    1421.0    1.052237e+09  26163.0
# Matt Damon                    1655.0    1.045076e+09  28177.0
# Leonardo DiCaprio             1127.0    1.038203e+09  16100.0
# Samuel L. Jackson             1380.0    1.030804e+09  24172.0
# Michael B. Jordan              676.0    1.023831e+09  12093.0
# Adam Sandler                   909.0    1.017324e+09  18120.0
# Emily Blunt                   1507.0    1.011284e+09  28195.0
# Ed Helms                      1195.0    9.931616e+08  24175.0
# Oscar Isaac                   1172.0    9.929217e+08  20146.0
# Anna Kendrick                 1640.0    9.902730e+08  32229.0
# Jesse Eisenberg               1483.0    9.701852e+08  28190.0

# %%
#Check actors
#Only shows one Star Wars movie b/c limited by imdb.title.principals data.  Carrie Fisher only has one actor row in the list.
Merged_People_Movie_Data.loc[(Merged_People_Movie_Data['primary_name'] == 'Carrie Fisher')]
# Out:
#          tconst           alternate_title           primary_title_x  \
# 7269  tt2527336  Star Wars: The Last Jedi  Star Wars: The Last Jedi
#
#                                original_title start_year  runtime_minutes  \
# 7269  Star Wars: Episode VIII - The Last Jedi       2017            152.0
#
#                         genres                   aka_title_year  \
# 7269  Action,Adventure,Fantasy  Star Wars: The Last Jedi - 2017
#
#                primary_title_y  lifetime_gross    year  \
# 7269  Star Wars: The Last Jedi     620181382.0  2017.0
#
#                            title_year     nconst category   primary_name
# 7269  Star Wars: The Last Jedi - 2017  nm0000402    actor  Carrie Fisher
