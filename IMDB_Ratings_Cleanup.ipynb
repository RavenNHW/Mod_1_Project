# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/cool data/imdb.title.ratings.csv.gz')
df.head
# Out:
# <bound method NDFrame.head of            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]>

# %%
newdf = df
newdf.drop(list(filter(lambda x: x < 100, df.numvotes)))
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73761 rows x 3 columns]

# %%
# Out:
# [31,
#  20,
#  21,
#  5,
#  74,
#  6,
#  21,
#  76,
#  6,
#  29,
#  21,
#  8,
#  17,
#  7,
#  6,
#  31,
#  15,
#  31,
#  40,
#  16,
#  9,
#  19,
#  86,
#  28,
#  27,
#  60,
#  14,
#  16,
#  83,
#  33,
#  67,
#  15,
#  64,
#  23,
#  19,
#  29,
#  9,
#  11,
#  20,
#  53,
#  55,
#  71,
#  7,
#  20,
#  34,
#  7,
#  36,
#  40,
#  75,
#  5,
#  14,
#  8,
#  79,
#  30,
#  32,
#  44,
#  14,
#  15,
#  63,
#  26,
#  34,
#  36,
#  10,
#  9,
#  23,
#  84,
#  32,
#  5,
#  23,
#  32,
#  56,
#  11,
#  64,
#  86,
#  88,
#  9,
#  63,
#  46,
#  25,
#  6,
#  23,
#  13,
#  21,
#  20,
#  10,
#  6,
#  73,
#  48,
#  9,
#  78,
#  52,
#  75,
#  75,
#  9,
#  6,
#  86,
#  8,
#  18,
#  10,
#  51,
#  13,
#  15,
#  10,
#  8,
#  5,
#  81,
#  52,
#  60,
#  76,
#  56,
#  6,
#  7,
#  9,
#  55,
#  9,
#  18,
#  8,
#  11,
#  5,
#  13,
#  5,
#  9,
#  15,
#  13,
#  41,
#  18,
#  6,
#  24,
#  8,
#  5,
#  24,
#  8,
#  7,
#  9,
#  19,
#  8,
#  10,
#  14,
#  37,
#  87,
#  9,
#  16,
#  27,
#  19,
#  12,
#  17,
#  18,
#  6,
# ...

# %%
df_over_100
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73761 rows x 3 columns]

# %%
fig = plt.figure(figsize=(20,10))
imdb_ratings = plt.scatter(
                    x = df_over_100.numvotes,
                    y = df_over_100.averagerating)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-92337ebfec78> in <module>
#       1 fig = plt.figure(figsize=(20,10))
#       2 imdb_ratings = plt.scatter(
# ----> 3                     x = df_over_100.numvotes,
#       4                     y = df_over_100.averagerating)
#
# ~\.conda\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'numvotes'
